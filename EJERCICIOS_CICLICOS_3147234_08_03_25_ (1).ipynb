# %% [markdown]
# 1.Leer un número y presentar la tabla de multiplicar de ese número entre 1 y 10. Utilizar el siguiente formato de ejemplo:

# %%
numero = int(input("Ingrese un número: "))

for i in range(1, 11):
    print(numero, "x", i, "=", numero * i)
# Out:
# Ingrese un número: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# 2.En un partido de fútbol, se ofrece un descuento a los aficionados que depende del estrato y la edad. Si el estrato es 1 y su edad es menor a 18 el descuento será del 20% sobre el valor de la boleta. Si el estrato es 1 y el alumno tiene 18 o mas años, el descuento será del 15%. Si el estrato es 2 y la edad es menor a 18 años, el descuento será del 10% y si el estrato es 2 y la edad es 18 años o más, el descuento será del 5%. Determinar el total del dinero recaudado y descontado por las últimas N personas que ingresan al partido.

# %%
cantidad_personas = int(input("Ingrese la cantidad de personas que ingresan: "))
valor_boleta = int(input("Ingrese el valor de la boleta: "))

total_recaudado = 0
total_descontado = 0

for i in range(cantidad_personas):
    print("Datos de la Persona", i + 1, ":")
    estrato = int(input("Ingrese el estrato (1 o 2): "))
    edad = int(input("Ingrese la edad: "))

    if estrato == 1:
        if edad < 18:
            descuento = 20
        else:
            descuento = 15
    elif estrato == 2:
        if edad < 18:
            descuento = 10
        else:
            descuento = 5
    else:
        print("Estrato no válido. No se aplicará descuento.")
        descuento = 0

    valor_descuento = (valor_boleta * descuento) // 100
    valor_a_pagar = valor_boleta - valor_descuento

    total_recaudado += valor_a_pagar
    total_descontado += valor_descuento

    print("Descuento aplicado:", valor_descuento)
    print("Valor a pagar:", valor_a_pagar)

print("Resumen final:")
print("Total recaudado:", total_recaudado)
print("Total descontado:", total_descontado)
# Out:
# Ingrese la cantidad de personas que ingresan: 2
# Ingrese el valor de la boleta: 112
# Datos de la Persona 1 :
# Ingrese el estrato (1 o 2): 4
# Ingrese la edad: 20
# Estrato no válido. No se aplicará descuento.
# Descuento aplicado: 0
# Valor a pagar: 112
# Datos de la Persona 2 :
# Ingrese el estrato (1 o 2): 1
# Ingrese la edad: 10
# Descuento aplicado: 22
# Valor a pagar: 90
# Resumen final:
# Total recaudado: 202
# Total descontado: 22

# %% [markdown]
# 3.Leer un password de ingreso a un programa y mostrar el mensaje de bienvenida si es correcto. Mientras no lo sea, debe mostrar el mensaje de Password incorrecto. El programa debe terminar automáticamente al quinto intento fallido.

# %%
password_correcto = "clave123"
intentos = 0

while intentos < 5:
    password_ingresado = input("Ingrese su contraseña: ")

    if password_ingresado == password_correcto:
        print("Ana12342")
        break
    else:
        print("Password incorrecto")
        intentos += 1

if intentos == 5:
    print("Demasiados intentos. Acceso bloqueado.")
# Out:
# Ingrese su contraseña: 123
# Password incorrecto
# Ingrese su contraseña: 45
# Password incorrecto
# Ingrese su contraseña: 12
# Password incorrecto
# Ingrese su contraseña: Ana1234
# Password incorrecto
# Ingrese su contraseña: 12
# Password incorrecto
# Demasiados intentos. Acceso bloqueado.
