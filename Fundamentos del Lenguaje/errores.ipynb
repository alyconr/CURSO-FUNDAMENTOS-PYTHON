# %%
while True:
    try:
        lista = [3, 5, 6, 8]
        pos = int(input("Ingrese la posición del elemento que desea obtener: "))
        print(f"El valor en la posición {pos} es {lista[pos]}")
        break
    except IndexError:
        print("El índice está fuera del rango.")
    except ValueError:
        print("Solo se permiten números enteros.")
# Out:
# Ingrese la posición del elemento que desea obtener: o
# Solo se permiten números enteros.
# Ingrese la posición del elemento que desea obtener: l
# Solo se permiten números enteros.
# Ingrese la posición del elemento que desea obtener: 9
# El índice está fuera del rango.
# Ingrese la posición del elemento que desea obtener: 6
# El índice está fuera del rango.
# Ingrese la posición del elemento que desea obtener: 3
# El valor en la posición 3 es 8

# %%
def agregar_una_vez(lista, el):
    try:
        if el in lista:
            raise ValueError(f"Error: Imposible añadir elementos duplicados => [{el}]")
        lista.append(el)
    except ValueError as e:
        print(e)

mi_lista = [1, 2, 3]
agregar_una_vez(mi_lista, 4)
agregar_una_vez(mi_lista, 2)

print("Gracias por usar este programa.")
# Out:
# Error: Imposible añadir elementos duplicados => [2]
# Gracias por usar este programa.
