# %% [markdown]
# APROPIACION

# %% [markdown]
# 1.Pregunte al usuario cuántos elementos desea ingresar en una lista, luego solicite cada uno de ellos y presente el contenido de la lista y su contenido invertido.

# %%
n = int(input("¿Cuántos elementos desea ingresar en la lista? "))
lista = []
for i in range(n):
  elemento = input(f"Ingrese el elemento {i+1}: ")
  lista.append(elemento)

print("Contenido lista:", lista)
print("Lista invertida:", lista[::-1])
# Out:
# ¿Cuántos elementos desea ingresar en la lista? 2
# Ingrese el elemento 1: h
# Ingrese el elemento 2: jjgj
# Contenido lista: ['h', 'jjgj']
# Lista invertida: ['jjgj', 'h']

# %% [markdown]
# 2.Crear una lista de números y solicitar un número. Borrar de la lista ese número en todas las posiciones donde se encuentre. Presentar la lista final

# %%
numeros = [1, 2, 3, 4, 2, 5, 6, 7, 5, 9, 7, 8, 10, 2 ,5 ]
print(numeros)
numEliminar = int(input("Ingrese un numero par eliminar"))
for x in numeros:
  if x == numEliminar:
    numeros.remove(x)
print(numeros)
# Out:
# [1, 2, 3, 4, 2, 5, 6, 7, 5, 9, 7, 8, 10, 2, 5]
# Ingrese un numero par eliminar8
# [1, 2, 3, 4, 2, 5, 6, 7, 5, 9, 7, 10, 2, 5]

# %% [markdown]
# 3.Solicite al usuario dos(2) frases y devuelva una lista con todas las letras que se repiten en la misma posición de ambas listas
# ejemplo: frase1: "holasena" frase2: "todogana" salida: ["o","n", "a"]

# %%
frase1 = input("Ingrese la primera frase: ")
frase2 = input("Ingrese la segunda frase: ")

letras_repetidas = []

longitud_minima = min(len(frase1), len(frase2))

for i in range(longitud_minima):
  if frase1[i] == frase2[i]:
    letras_repetidas.append(frase1[i])

print("Letras repetidas en la misma posición:", letras_repetidas)
# Out:
# Ingrese la primera frase: camila
# Ingrese la segunda frase: camilo
# Letras repetidas en la misma posición: ['c', 'a', 'm', 'i', 'l']
