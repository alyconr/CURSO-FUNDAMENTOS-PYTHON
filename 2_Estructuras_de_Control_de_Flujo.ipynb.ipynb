# %% [markdown]
# Apropiación [Ejercicios Cíclicos]

# %% [markdown]
# 1. Leer un número y presentar la tabla de multiplicar de ese número entre 1 y 10. Utilizar el siguiente formato de ejemplo:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5

# %%
#Se definen variables
numero = int(input("Ingrese el numero"))
#Se define el rango a trabajar
for i in range(1,11):
  #Se define la formula y se imprime el resultado
     print(f"{numero}x{i}={numero*i}")
# Out:
# Ingrese el numero2
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20

# %% [markdown]
# 2. En un partido de fútbol, se ofrece un descuento a los aficionados que depende del estrato y la edad. Si el estrato es 1 y su edad es menor a 18 el descuento será del 20% sobre el valor de la boleta. Si el estrato es 1 y el alumno tiene 18 o mas años, el descuento será del 15%. Si el estrato es 2 y la edad es menor a 18 años, el descuento será del 10% y si el estrato es 2 y la edad es 18 años o más, el descuento será del 5%. Determinar el total del dinero recaudado y descontado por las últimas N personas que ingresan al partido.

# %%
# Se definen las variables y su valor
#Ingresamos la formula para hallar el descuento
def calcular_recaudacion_y_descuento(n, precio_boleta):
    total_recaudado = 0
    total_descuento = 0
#Se establecen las condicionales y su negación
    for _ in range(n):
        estrato = int(input("Ingrese el estrato (1 o 2): "))
        edad = int(input("Ingrese la edad: "))

        if estrato == 1:
            if edad < 18:
                descuento = 0.20
            else:
                descuento = 0.15
        elif estrato == 2:
            if edad < 18:
                descuento = 0.10
            else:
                descuento = 0.05
        else: #Se imprime "estrato no valido en caso de que se ingrese algun numero diferente a uno o dos"
            print("Estrato no válido. Debe ser 1 o 2.")
            continue

        # Calculamos el valor del descuento y el precio final
        valor_descuento = precio_boleta * descuento
        precio_final = precio_boleta - valor_descuento

       #se cambia el valor de las variables
        total_recaudado += precio_final
        total_descuento += valor_descuento

    return total_recaudado, total_descuento

n = int(input("Ingrese el número de personas: "))
precio_boleta = float(input("Ingrese el precio de la boleta: "))

total_recaudado, total_descuento = calcular_recaudacion_y_descuento(n, precio_boleta)

print(f"Total recaudado: {total_recaudado:.2f}")#se imprime el resultado
print(f"Total descuento: {total_descuento:.2f}")#se imprime el resultado
# Out:
# Ingrese el número de personas: 3
# Ingrese el precio de la boleta: 20000
# Ingrese el estrato (1 o 2): 1
# Ingrese la edad: 19
# Ingrese el estrato (1 o 2): 2
# Ingrese la edad: 23
# Ingrese el estrato (1 o 2): 1
# Ingrese la edad: 34
# Total recaudado: 53000.00
# Total descontado: 7000.00

# %% [markdown]
# 3. Leer un password de ingreso a un programa y mostrar el mensaje de bienvenida si es correcto. Mientras no lo sea, debe mostrar el mensaje de Password incorrecto. El programa debe terminar automáticamente al quinto intento fallido.

# %%
#Se definen las variables
password = input("Ingrese el password: ")
#Se define el condicional
for i in range(5):#Se usa el rango para repetir el proceso 5 veces, al quinto intento el programa se cierra
  if password == "12345":
    print("Bienvenido")#En caso de que la contraseña sea correcta se imprime el mensaje de "bienvenido"
    break
  else:
  #Se imprime el resultado
    print("Password incorrecto", i)
    password = input("Ingrese el password: ")
    print("Intento fallido")
# Out:
# Ingrese el password: 12345
# Bienvenido
