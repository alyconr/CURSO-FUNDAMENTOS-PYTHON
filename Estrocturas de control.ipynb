# %%
if condicion:
  codigo
  codigo

# %%
edad = int(input("Ingrese su edd"))

if edad>=18:
  print("Usted es mayor de edad y puede votar")
# Out:
# Ingrese su edd18
# Usted es mayor de edad y puede votar

# %%
if condicion:
  codigo
  codigo
  else:
    codigo
    codigo
# Out:
#   File "<ipython-input-4-3ac1968c6e4a>", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
edad = int(input("Ingrese su edd"))
if edad>=18:
  print("Usted es mayor de edad y puede votar")
else:
    print("Usted es menor de edad y no puede votar")
# Out:
# Ingrese su edd18
# Usted es mayor de edad y puede votar

# %%
edad = int(input("Ingrese su edad:"))

if edad>=18:
  print("Usted es mayor de edad y puede votar")
else:
    print("Usted es menor de edad y no puede votar")

    print("Fin del programa viva la democracia")
# Out:
# Ingrese su edad:18
# Usted es mayor de edad y puede votar

# %%
if condicion:
  codigo
  codigo
  elif condicion:
    codigo
    codigo
  elif condicion:
    codigo
    codigo
  else:
    codigo
    codigo

# %%
edad = int(input("Ingrese su edad:"))

if edad>=18:
  print("Usted es mayor de edad y puede votar")
elif edad>=16:
    print("Usted es menor de edad pero puede votar con autorización")
else:
    print("Usted es menor de edad y no puede votar")

    print("Fin del programa viva la democracia")

# %%
fruta=input("Ingrese el nombre de una fruta:")
if fruta == "banano":
  print("El nombre de la fruta es banano")
elif fruta == "manzana":
  print("El nombre de la fruta es manzana")
elif fruta == "pera":
  print("El nombre de la fruta es pera")
elif fruta == "uva":
  print("El nombre de la fruta es uva")
else:
  print("El nombre de la fruta no es banano, manzana,pera,uba,fruta no reconocida")
# Out:
# Ingrese el nombre de una fruta:banano
# El nombre de la fruta es banano

# %%
if condicion:
  codigo
  codigo
  if condicion:
    codigo
    codigo

# %%
edad = int(input("Ingrese su edad:"))

if edad>=18:
  print("Usted es mayor de edad y puede votar")
  if edad>=21:
    print("Usted es mayor de edad y puede beber alcohol")
# Out:
# Ingrese su edad:30
# Usted es mayor de edad y puede votar
# Usted es mayor de edad y puede beber alcohol

# %%
edad = int(input("Ingrese su edad:"))

if edad>=18:
  print("Usted es mayor de edad y puede votar")
else:
      if edad>16:
        print("Usted es menor de edad pero puede votar con autorización")
      else:
       print("Usted es menor de edad y no puede votar")
# Out:
# Ingrese su edad:20
# Usted es mayor de edad y puede votar

# %% [markdown]
# Operadores Logicos

# %% [markdown]
# ush

# %%
edad = int(input("Ingrese su edad: "))
estado_civil = input("Ingrese su estado civil: ")
buena_persona = input("Ingrese si es buena persona (si/no): ")
aspecto_bonito = input("Ingrese si es bonito (si/no): ")

if (edad == 20) and (estado_civil.lower() == "soltero") and (buena_persona.lower() == "si") and (aspecto_bonito.lower() == "si"):
  print("bien")
else:
  print("mal")
# Out:
# Ingrese su edad: 20
# Ingrese su estado civil: soltero
# Ingrese si es buena persona (si/no): si
# Ingrese si es bonito (si/no): si
# bien

# %% [markdown]
# 1. En un sistema de automatización industrial, un motor puede estar encendido o apagado. Si la temperatura de la máquina supera los 80 grados, el motor debe apagarse automáticamente. Escribir un programa que controle el estado del motor y lo apague si la temperatura supera los 80 grados.

# %%
temperatura = int(input("Ingrese la temperatura: "))
if temperatura <80:
  print("no pasa nada bro no va a explotar jajaja")
else:
  print("apagate o explotas")
# Out:
# Ingrese la temperatura: 79
# no pasa nada bro no va a explotar jajaja

# %% [markdown]
# 2. Una universidad ofrece un descuento a los estudiantes que depende del estrato y la edad. Si el estrato es 1 y su edad es menor a 18 el descuento será del 20% sobre el valor de la matrícula. Si el estrato es 1 y el alumno tiene 18 o mas años, el descuento será del 15%. Si el estrato es 2 y la edad es menor a 18 años, el descuento será del 10% y si el estrato es 2 y la edad es 18 años o mas, el descuento será del 5%.
# Escribir el precio que deberá pagar un estudiante por su matrícula y el valor del descuento.

# %%
estrato = int(input("Ingrese su estrato: "))
edad = int(input("Ingrese su edad: "))
precio = int(input("Ingrese el valor de la matrícula: "))

if (estrato == 1) and (edad < 18):
  descuento = precio * 0.20
  precio = precio - descuento
  print(f"Tiene un descuento del 20%: ${precio:.0f}" )
elif (estrato == 1) and (edad >= 18):
  descuento = precio * 0.15
  precio = precio - descuento
  print(f"Tiene un descuento del 15%: ${precio:.0f}")
elif (estrato == 2) and (edad < 18):
  descuento = precio * 0.10
  print(f"Tiene un descuento del 10%: ${precio:.0f}")
elif (estrato == 2) and (edad >= 18):
  descuento = precio * 0.05
  precio = precio - descuento
  print(f"Tiene un descuento del 5%: ${precio:.0f}")
else:
  print("No tiene descuento")
# Out:
# Ingrese su estrato: 1
# Ingrese su edad: 16
# Ingrese el valor de la matrícula: 1000000
# Tiene un descuento del 20%: $800000

# %% [markdown]
# 3. En un sistema de control de calidad, se deben inspeccionar las piezas de un producto para determinar si cumplen con los estándares de calidad. Si la pieza es defectuosa, se debe marcar como rechazada y enviar una alerta al operador. Si la pieza cumple con los estándares de calidad, se debe marcar como aprobada y continuar con la producción.
# Realice un programa que lea una entrada binaria en la que los 1s significan estándares de calidad cumplidos y los Os significan estándares de calidad No cumplidos. El programa debe rechazar la pieza ante cualquier estándar no cumplido.

# %%
num_pieza = int(input("Ingrese el numero de piezas: "))
if num_pieza == 11111111:
  print("La pieza es aprobada")
else:
  print("La pieza es rechazada")
# Out:
# Ingrese el numero de piezas: 10111111
# La pieza es rechazada

# %% [markdown]
# El ciclo wile

# %%
while condicion:
  codigo
  codigo

# %%
x=1
while x<=5:
  print(x)
  x+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
color = "rojo"
while color !="verde":
  color = input("Ingrese el color: ")
  print("El color seleccionado fue:",color)
# Out:
# Ingrese el color: rosa
# El color seleccionado fue: rosa
# Ingrese el color: rojo
# El color seleccionado fue: rojo
# Ingrese el color: amarillo
# El color seleccionado fue: amarillo
# Ingrese el color: verde
# El color seleccionado fue: verde

# %% [markdown]
# El ciclo for

# %%
for variable in interabale:
  codigo
  codigo

# %%
cad = [1,23,5,80,3, "casa", 2.4, "sena", 21]
for x in cad:
  print(x)
# Out:
# 1
# 23
# 5
# 80
# 3
# casa
# 2.4
# sena
# 21

# %%
for x in range (5):
  print("hola",x+1)
# Out:
# hola 1
# hola 2
# hola 3
# hola 4
# hola 5

# %%
for x in range (1,11,2):
  print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for x in range(0,5,1):
  print("hola",x)
# Out:
# hola 0
# hola 1
# hola 2
# hola 3
# hola 4

# %%
for x in range(10):
  print("hola",x)
# Out:
# hola 0
# hola 1
# hola 2
# hola 3
# hola 4
# hola 5
# hola 6
# hola 7
# hola 8
# hola 9

# %%
for x in range(9,0,-1):
  print(x)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
for x in range(3,100,3):
  print(x)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %%
nombre = input("Ingrese su nombre: ")
for x  in range(1, len(nombre), 2):
  print(x)
# Out:
# Ingrese su nombre: samuel
# 1
# 3
# 5

# %% [markdown]
# BReak y continue

# %%
print("La instruccion break: ")
for i in range(1,6):
  if i == 3:
    break
  print("Dentro del ciclo", i)
print("Fuera del ciclo")
# Out:
# La instruccion break:
# Dentro del ciclo 1
# Dentro del ciclo 2
# Fuera del ciclo

# %%
print("La instruccion break: ")
for i in range(1,6):
  if i == 4:
    continue
  print("Dentro del ciclo", i)
print("Fuera del ciclo")
# Out:
# La instruccion break:
# Dentro del ciclo 1
# Dentro del ciclo 2
# Dentro del ciclo 3
# Dentro del ciclo 5
# Fuera del ciclo

# %% [markdown]
# Apropiacion [ejercicios]

# %% [markdown]
# Apropiación [Ejercicios Cíclicos]
#
# Leer un número y presentar la tabla de multiplicar de ese número entre 1 y 10. Utilizar el siguiente formato de ejemplo:
#
# 1 x 1 = 1
#
# 1 x 2 = 2
#
# 1 x 3 = 3
#
# 1 x 4 = 4
#
# 1 x 5 = 5

# %%
numero = int(input("Ingrese un número para la tabla: "))

for x in range(1, 11):
    resultado = numero * x
    print(numero, "x", x, "=", resultado)
# Out:
# Ingrese un número para la tabla: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# 2. En un partido de fútbol, se ofrece un descuento a los aficionados que depende del estrato y la edad. Si el estrato es 1 y su edad es menor a 18 el descuento será del 20% sobre el valor de la boleta. Si el estrato es 1 y el alumno tiene 18 o mas años, el descuento será del 15%. Si el estrato es 2 y la edad es menor a 18 años, el descuento será del 10% y si el estrato es 2 y la edad es 18 años o más, el descuento será del 5%. Determinar el total del dinero recaudado y descontado por las últimas N personas que ingresan al partido.

# %%
precio_boleta = int(input("Ingrese el valor de la boleta: "))
N = int(input("Ingrese el número de personas: "))


total_recaudado = 0
total_descuento = 0


for i in range(N):
    print(f"\nPersona {i + 1}:")
    estrato = int(input("Ingrese el estrato (1 o 2): "))
    edad = int(input("Ingrese la edad: "))


    if estrato == 1:
        if edad < 18:
            descuento = precio_boleta * 0.20
        else:
            descuento = precio_boleta * 0.15
    elif estrato == 2:
        if edad < 18:
            descuento = precio_boleta * 0.10
        else:
            descuento = precio_boleta * 0.05
    else:
        print("Estrato no válido. No se aplicará descuento.")
        descuento = 0.0


    precio_final = precio_boleta - descuento


    total_recaudado += precio_final
    total_descuento += descuento


    print(f"Descuento aplicado: ${descuento:.0f}")
    print(f"Precio final: ${precio_final:.0f}")


print("\nResumen Final:")
print(f"Total recaudado: ${total_recaudado:.0f}")
print(f"Total descontado: ${total_descuento:.0f}")
# Out:
# Ingrese el valor de la boleta: 5000
# Ingrese el número de personas: 3
#
# Persona 1:
# Ingrese el estrato (1 o 2): 1
# Ingrese la edad: 16
# Descuento aplicado: $1000
# Precio final: $4000
#
# Persona 2:
# Ingrese el estrato (1 o 2): 2
# Ingrese la edad: 17
# Descuento aplicado: $500
# Precio final: $4500
#
# Persona 3:
# Ingrese el estrato (1 o 2): 1
# Ingrese la edad: 20
# Descuento aplicado: $750
# Precio final: $4250
#
# Resumen Final:
# Total recaudado: $12750
# Total descontado: $2250

# %% [markdown]
# 3. Leer un password de ingreso a un programa y mostrar el mensaje de bienvenida si es correcto. Mientras no lo sea, debe mostrar el mensaje de Password incorrecto. El programa debe terminar automáticamente al quinto intento fallido.

# %%
intentos_maximos = 5
password = input("Ingrese el password: ")
for i in range(intentos_maximos):
  print(f"\nintento numero {i + 1} de 5:")
  password_val = input("Ingrese el password: ")
  if password_val == password:
      print("password correcto")
      break

else:
        print("erro tristemente")
# Out:
# Ingrese el password: sa
#
# intento numero 1 de 5:
# Ingrese el password: sa
# password correcto
