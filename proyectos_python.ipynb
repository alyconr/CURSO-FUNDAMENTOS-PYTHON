# %%
# 1. Calcular el índice de cosecha
def indice_cosecha(frutos_recolectados, frutos_producidos):
    if frutos_producidos == 0:
        return 0  # Evitar división por cero
    return (frutos_recolectados / frutos_producidos) * 100

# Ejemplo de uso para el índice de cosecha
frutos_recolectados = float(input("Ingrese la cantidad de frutos recolectados: "))
frutos_producidos = float(input("Ingrese la cantidad de frutos producidos: "))
indice = indice_cosecha(frutos_recolectados, frutos_producidos)
print(f"Índice de cosecha: {indice:.2f}%")

# %%
#se da el print para imprimir los datos de la letra
print('\n'.join(['"-----"', '[     ]', '[     ]','[     ]','[     ]','[     ]','[     ]','[     ]', '"-----"', '[    ', '[    ', '[    ','[   ']))
# Out:
# "-----"
# [     ]
# [     ]
# [     ]
# [     ]
# [     ]
# [     ]
# [     ]
# "-----"
# [
# [
# [
# [

# %%
#variables de los parciales
parcial1 = float(input("Ingrese la primera calificación parcial: "))
parcial2 = float(input("Ingrese la segunda calificación parcial: "))
parcial3 = float(input("Ingrese la tercera calificación parcial: "))
examen_final = float(input("Ingrese la calificación del examen final: "))
trabajo_final = float(input("Ingrese la calificación del trabajo final: "))
#se hacen los ajustes o las operaciones
promedio_parciales = (parcial1 + parcial2 + parcial3) / 3
calificacion_final = (promedio_parciales * 0.55) + (examen_final * 0.30) + (trabajo_final * 0.15)
#se da la funcion que imprime los datos
print(f"La calificación final es: {calificacion_final:.2f}")

# %%
#se da variable y la funcion
frases = input("Escrbie la fase aca: ")
#se añade una variable y se usa len y split, len lee las palabras o frases y split divide las frases
cuantas_palabras = len(frases.split())
#se añalle el print para imprimit las frases
print(f"numero de palabras en la frase: {cuantas_palabras}")

# %%
# Se solicita una frase al usuario
frase = input("Ingresa tu frase: ")

# Se convierte la frase a mayúsculas y se invierte
frase_M = frase.upper()[::-1]

# Se muestra el resultado
print(f"Resultado de la frase: {frase_M}")
