# %% [markdown]
# <a href="https://colab.research.google.com/github/julian-bohrquez12/CURSO-FUNDAMENTOS-PYTHON-3/blob/Rama-solucion/Ejercicios_a_evaluar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Gestión de Inventario de Productos Descripción: Se debe desarrollar un sistema que administre un inventario compuesto por productos y sus cantidades. El programa presentará el listado inicial y resaltará aquellos artículos cuyo stock esté por debajo de un umbral definido. Luego, permitirá actualizar la cantidad de un producto específico, mostrando el inventario antes y después de la modificación.

# %%
inventario = ["carpeta","lapiz","regla","cuaderno"]
cantidad_productos = [20,40,50,30]
stock =10



for i in range (len(inventario)) :
  print(f"{i + 1}. {inventario[i]}: {cantidad_productos[i]}")
  if cantidad_productos [i] < stock:
    print("El producto esta por debajo del stock: ")
    print(f"El inventario {inventario[i]} no tiene suficiente stock: {cantidad_productos[i]} cantidad_productos")

inventario_seleccionado = int(input("ingrese el numero del producto que se desea actualizar: "))
valor = int (input("ingrese la nueva cantidad: "))

cantidad_productos[inventario_seleccionado - 1] = valor

for i in range (len(inventario)):
  print(f"{i + 1}. {inventario[i]}: {cantidad_productos[i]}")
  if cantidad_productos [i] < stock:
    print("El producto esta por debajo del stock: ")
    print(f"el inventario {inventario[i]} no tiene suficiente stock: {cantidad_productos[i]} cantidad_productos")
# Out:
# 1. carpeta: 20
# 2. lapiz: 40
# 3. regla: 50
# 4. cuaderno: 30
# ingrese el numero del producto que se desea actualizar: 3
# ingrese la nueva cantidad: 80
# 1. carpeta: 20
# 2. lapiz: 40
# 3. regla: 80
# 4. cuaderno: 30

# %% [markdown]
# 2.Búsqueda de Palabras en un Texto Descripción: Crea una aplicación que solicite al usuario un párrafo y, a continuación, le permita buscar una palabra específica. El sistema debe contar cuántas veces aparece dicha palabra en el texto, mostrar las posiciones donde se encuentra (sin distinguir mayúsculas de minúsculas) y comunicar el resultado al usuario

# %%
parrafo= input("ingese el parrafo: ").lower()
print(parrafo)

buscar_palabra =(input("ingrese una palabra que quiere buscar: "))


numero_palabra = parrafo.count(buscar_palabra)


print(f"la palabra  ´{buscar_palabra}' esta '{numero_palabra}'veces en el parrafo")
# Out:
# ingese el parrafo: holis mañana no hay clase pero hay asado
# holis mañana no hay clase pero hay asado
# ingrese una palabra que quiere buscar: hay
# la palabra  ´hay' esta '2'veces en el parrafo

# %% [markdown]
# 3.Conversión y Limpieza de Texto Descripción: Diseña una solución que pida al usuario una frase, la divida en palabras y elimine cualquier carácter no alfabético de cada una. Una vez procesada la información, la estructura resultante se transformará en una forma inmutable, y se presentará el contenido final al usuario de manera ordenada.

# %%
import string

frase = input("Ingresa una frase: ")


palabras = frase.split()

palabras_procesadas = []
for palabra in palabras:
    palabra_limpia = "".join([letra for letra in palabra if letra.isalpha()])
    palabras_procesadas.append(palabra_limpia)

resultado = tuple(palabras_procesadas)

print(sorted(resultado))
# Out:
# Ingresa una frase: hola carolina todo ben por alla
# ['alla', 'ben', 'carolina', 'hola', 'por', 'todo']

# %% [markdown]
# 4.Registro y Consulta de Calificaciones de Exámenes Descripción: Implementa un sistema que gestione un registro de estudiantes y sus calificaciones. El programa debe permitir agregar nuevos registros, listar todos los existentes y consultar la calificación de un estudiante introduciendo su nombre. Se espera que la información se actualice y se presente de forma clara en cada paso.

# %%
registros = {}

while True:
    print("\nOpciones:")
    print("1. Agregar nuevo registro")
    print("2. Listar todos los registros")
    print("3. Consultar calificación de un estudiante")
    print("4. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        nombre = input("Nombre del estudiante: ")
        calificacion = input("Calificación: ")
        registros[nombre] = calificacion
        print(f"Registro agregado: {nombre} - {calificacion}")

    elif opcion == "2":
        if registros:
            print("\nRegistros de calificaciones:")
            for nombre, calificacion in registros.items():
                print(f"{nombre}: {calificacion}")
        else:
            print("No hay registros disponibles.")

    elif opcion == "3":
        nombre = input("Ingrese el nombre del estudiante: ")
        if nombre in registros:
            print(f"Calificación de {nombre}: {registros[nombre]}")
        else:
            print("Estudiante no encontrado.")

    elif opcion == "4":
        print("Saliendo del programa...")
        break

    else:
        print("Opción no válida. Intente de nuevo.")
# Out:
# Opciones:
# 1. Agregar nuevo registro
# 2. Listar todos los registros
# 3. Consultar calificación de un estudiante
# 4. Salir
# Selecciona una opción: 1
# Nombre del estudiante: carlos
# Calificación: 90
# Registro agregado: carlos - 90
#
# Opciones:
# 1. Agregar nuevo registro
# 2. Listar todos los registros
# 3. Consultar calificación de un estudiante
# 4. Salir
# Selecciona una opción: 2
#
# Registros de calificaciones:
# carlos: 90
#
# Opciones:
# 1. Agregar nuevo registro
# 2. Listar todos los registros
# 3. Consultar calificación de un estudiante
# 4. Salir
# Selecciona una opción: 3
# Ingrese el nombre del estudiante: mario
# Estudiante no encontrado.
#
# Opciones:
# 1. Agregar nuevo registro
# 2. Listar todos los registros
# 3. Consultar calificación de un estudiante
# 4. Salir
# Selecciona una opción: 4
# Saliendo del programa...

# %% [markdown]
# 5.Calculadora de Estadísticas de Números Descripción: Desarrolla una aplicación que trabaje con una colección de números predefinidos. El sistema debe ofrecer al usuario un menú interactivo con opciones para calcular el promedio, identificar el valor máximo y mínimo, o eliminar un número. Tras cada operación, se mostrará tanto el resultado como el estado actual de la colección.

# %%
numeros = [10, 20, 30, 40, 50]

while True:
    print("\nOpciones:")
    print("1. Calcular promedio")
    print("2. Identificar valor máximo")
    print("3. Identificar valor mínimo")
    print("4. Eliminar un número")
    print("5. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        if numeros:
            promedio = sum(numeros) / len(numeros)
            print(f"Promedio: {promedio:.2f}")
        else:
            print("La lista está vacía.")

    elif opcion == "2":
        if numeros:
            print(f"Valor máximo: {max(numeros)}")
        else:
            print("La lista está vacía.")

    elif opcion == "3":
        if numeros:
            print(f"Valor mínimo: {min(numeros)}")
        else:
            print("La lista está vacía.")

    elif opcion == "4":
        if numeros:
            try:
                num = int(input("Ingrese el número a eliminar: "))
                if num in numeros:
                    numeros.remove(num)
                    print(f"Número {num} eliminado.")
                else:
                    print("El número no está en la lista.")
            except ValueError:
                print("Entrada no válida. Ingrese un número entero.")
        else:
            print("La lista está vacía.")

    elif opcion == "5":
        print("Saliendo del programa...")
        break

    else:
        print("Opción no válida. Intente de nuevo.")

    print(f"Estado actual de la colección: {numeros}")
# Out:
# Opciones:
# 1. Calcular promedio
# 2. Identificar valor máximo
# 3. Identificar valor mínimo
# 4. Eliminar un número
# 5. Salir
# Selecciona una opción: 1
# Promedio: 30.00
# Estado actual de la colección: [10, 20, 30, 40, 50]
#
# Opciones:
# 1. Calcular promedio
# 2. Identificar valor máximo
# 3. Identificar valor mínimo
# 4. Eliminar un número
# 5. Salir
# Selecciona una opción: 2
# Valor máximo: 50
# Estado actual de la colección: [10, 20, 30, 40, 50]
#
# Opciones:
# 1. Calcular promedio
# 2. Identificar valor máximo
# 3. Identificar valor mínimo
# 4. Eliminar un número
# 5. Salir
# Selecciona una opción: 3
# Valor mínimo: 10
# Estado actual de la colección: [10, 20, 30, 40, 50]
#
# Opciones:
# 1. Calcular promedio
# 2. Identificar valor máximo
# 3. Identificar valor mínimo
# 4. Eliminar un número
# 5. Salir
# Selecciona una opción: 4
# Ingrese el número a eliminar: 50
# Número 50 eliminado.
# Estado actual de la colección: [10, 20, 30, 40]
#
# Opciones:
# 1. Calcular promedio
# ...
