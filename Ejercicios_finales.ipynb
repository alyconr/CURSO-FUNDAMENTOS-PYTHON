# %% [markdown]
# # Ejercicios para aplicar funciones, estructuras de control, colecciones, módulos y manejo de excepciones
#
# ---
#
# ## Ejercicio 1: Calculadora Avanzada
#
# **Descripción:**
# Crea una función que actúe como calculadora. La función recibirá dos números y un operador (por ejemplo, '+', '-', '*', '/', '**', '//') para realizar la operación correspondiente.
# - Utiliza estructuras de control (if/else) para seleccionar la operación a realizar.
# - Usa manejo de excepciones para controlar errores como la división por cero y entradas no numéricas.
# - Puedes importar el módulo `math` para operaciones adicionales si es necesario.
#
# **Ejemplo de salida:**
#
# Ingrese el primer número: 10
# Ingrese el segundo número: 5
# Ingrese el operador (+, -, *, /, **, //): /
# Resultado: 10 / 5 = 2.0

# %%
def calculadora_avanzada():
    try:
        num1 = float(input("Ingrese el primer número: "))
        num2 = float(input("Ingrese el segundo número: "))
        operador = input("Ingrese el operador (+, -, *, /, **, //): ")

        if operador == '+':
            resultado = num1 + num2
        elif operador == '-':
            resultado = num1 - num2
        elif operador == '*':
            resultado = num1 * num2
        elif operador == '/':
            if num2 == 0:
                raise ZeroDivisionError("No se puede dividir por cero.")
            resultado = num1 / num2
        elif operador == '**':
            resultado = num1 ** num2
        elif operador == '//':
            if num2 == 0:
                raise ZeroDivisionError("No se puede dividir por cero.")
            resultado = num1 // num2
        else:
            raise ValueError("Operador no válido.")

        print(f"Resultado: {num1} {operador} {num2} = {resultado}")
    except Exception as e:
        print("Error:", e)

calculadora_avanzada()
# Out:
# Ingrese el primer número: 57
# Ingrese el segundo número: 10
# Ingrese el operador (+, -, *, /, **, //): *
# Resultado: 57.0 * 10.0 = 570.0

# %% [markdown]
# ---
#
# ## Ejercicio 2: Administrador de Inventarios
#
# **Descripción:**
# Desarrolla un sistema para gestionar el inventario de productos usando un diccionario donde cada clave es el nombre del producto y su valor la cantidad en stock.
# - Implementa funciones para agregar, actualizar y eliminar productos.
# - Utiliza estructuras de control para recorrer y mostrar el inventario.
# - Incluye manejo de excepciones para capturar intentos de actualizar o eliminar un producto inexistente.
#
# **Ejemplo de salida:**
# Inventario inicial: {'manzanas': 50, 'naranjas': 30, 'peras': 20}
# Actualizando stock de 'peras' a 25...
# Producto 'bananas' agregado con 40 unidades.
# Eliminando 'naranjas'...
# Inventario final: {'manzanas': 50, 'peras': 25, 'bananas': 40}

# %%
def administrador_inventario():
    inventario = {'Fresas': 20, 'cerezas': 15, 'frambuesas': 23}
    while True:
        print("\n Menú ")
        print("1. Agregar producto")
        print("2. Actualizar stock")
        print("3. Eliminar producto")
        print("4. Ver inventario")
        print("5. Salir")
        opcion = input("Seleccione una opción: ")
        try:
            if opcion == '1':
                prod = input("Nombre del producto: ").lower()
                cant = int(input("Cantidad: "))
                inventario[prod] = cant
                print(f"Producto '{prod}' agregado con {cant} unidades.")
            elif opcion == '2':
                prod = input("Producto a actualizar: ").lower()
                if prod in inventario:
                    cant = int(input("Nueva cantidad: "))
                    inventario[prod] = cant
                    print(f"Stock de '{prod}' actualizado a {cant}.")
                else:
                    raise KeyError("Producto no encontrado.")
            elif opcion == '3':
                prod = input("Producto a eliminar: ").lower()
                if prod in inventario:
                    del inventario[prod]
                    print(f"Producto '{prod}' eliminado.")
                else:
                    raise KeyError("Producto no encontrado.")
            elif opcion == '4':
                print("Inventario actual:", inventario)
            elif opcion == '5':
                break
            else:
                print("Opción no válida.")
        except Exception as e:
            print("Error:", e)
administrador_inventario()
# Out:
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 1
# Nombre del producto: Moras
# Cantidad: 30
# Producto 'moras' agregado con 30 unidades.
#
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 2
# Producto a actualizar: Fresas
# Error: 'Producto no encontrado.'
#
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 2
# Producto a actualizar: cerezas
# Nueva cantidad: 29
# Stock de 'cerezas' actualizado a 29.
#
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 3
# Producto a eliminar: frambuesas
# Producto 'frambuesas' eliminado.
#
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 4
# Inventario actual: {'Fresas': 20, 'cerezas': 29, 'moras': 30}
#
#  Menú
# 1. Agregar producto
# 2. Actualizar stock
# 3. Eliminar producto
# 4. Ver inventario
# 5. Salir
# Seleccione una opción: 5

# %% [markdown]
# ---
#
# ## Ejercicio 3: Análisis de Texto
#
# **Descripción:**
# Crea una función que reciba una cadena de texto y calcule la frecuencia de cada palabra en el mismo.
# - Convierte el texto a minúsculas y separa las palabras usando algún método (puedes utilizar expresiones regulares con el módulo `re`).
# - Emplea un diccionario para almacenar la palabra (clave) y su frecuencia (valor).
# - Controla excepciones en caso de que el usuario no ingrese ningún texto o ingrese caracteres inesperados.
#
# **Ejemplo de salida:**
# Ingrese un texto: "Hola mundo, hola a todos en el mundo"
# Frecuencia de palabras: hola: 2
# mundo: 2
# a: 1
# todos: 1
# en: 1
# el: 1

# %%
import re
def analisis_texto():
    try:
        texto = input("Ingrese un texto: ")
        if not texto.strip():
            raise ValueError("Texto vacío.")
        palabras = re.findall(r'\b\w+\b', texto.lower())
        frecuencia = {}
        for palabra in palabras:
            frecuencia[palabra] = frecuencia.get(palabra, 0) + 1
        print("Frecuencia de palabras:")
        for palabra, cantidad in sorted(frecuencia.items(), key=lambda item: item[1], reverse=True):
            print(f"{palabra}: {cantidad}")
    except ValueError as e:
        print("Error:", e)
    except Exception as e:
        print("Error inesperado:", e)
analisis_texto()
# Out:
# Ingrese un texto: Python es paz, python es arte
# Frecuencia de palabras:
# python: 2
# es: 2
# paz: 1
# arte: 1

# %% [markdown]
# ---
#
# ## Ejercicio 4: Conversor de Unidades
#
# **Descripción:**
# Desarrolla un conjunto de funciones para convertir unidades métricas. Por ejemplo:
# - De centímetros a pulgadas.
# - De kilómetros a millas.
# Utiliza estructuras de control para verificar que la entrada sea numérica, y maneja excepciones cuando el usuario ingrese datos inválidos.
#
# **Ejemplo de salida:**
# Seleccione la conversión:
#
# Centímetros a pulgadas
#
# Kilómetros a millas
# Opción: 1
# Ingrese la cantidad en centímetros: 100
# Resultado: 100 cm = 39.37 pulgadas

# %%
def conversor_unidades():
    try:
        print("seleccione la conversión:")
        print("1.centímetros a pulgadas")
        print("2.kilómetros a millas")
        opcion = input("Opción: ")
        if opcion == '1':
            cantidad = float(input("ingrese la cantidad en centímetros: "))
            if cantidad < 0:
                raise ValueError("la cantidad no puede ser negativa.")
            print(f"{cantidad} cm = {cantidad / 2.54:.2f} pulgadas")
        elif opcion == '2':
            cantidad = float(input("ingrese la cantidad en kilómetros: "))
            if cantidad < 0:
                raise ValueError("la cantidad no puede ser negativa.")
            print(f"{cantidad} km = {cantidad * 0.621371:.2f} millas")
        else:
            print("opción no válida, por favor, seleccione una opción válida.")
    except ValueError as e:
        print(f"error", e)
    except Exception as e:
        print("error inesperado:", e)
conversor_unidades()
# Out:
# seleccione la conversión:
# 1.centímetros a pulgadas
# 2.kilómetros a millas
# Opción: 2
# ingrese la cantidad en kilómetros: 800
# 800.0 km = 497.10 millas

# %% [markdown]
# ---
#
# ## Ejercicio 5: Juego "Adivina el Número"
#
# **Descripción:**
# Implementa un juego en el que la computadora selecciona aleatoriamente un número en un rango (por ejemplo, 1 a 50) y el usuario debe adivinarlo.
# - Emplea el módulo `random` para generar el número secreto.
# - Utiliza un bucle que permita múltiples intentos, con retroalimentación indicando si el número ingresado es mayor o menor que el secreto.
# - Gestiona excepciones para capturar entradas no numéricas.
#
# **Ejemplo de salida:**
# ¡Bienvenido al juego "Adivina el Número"!
# Estoy pensando en un número entre 1 y 50.
# Intento 1 - Ingresa tu número: 25
# El número secreto es mayor.
# Intento 2 - Ingresa tu número: 35
# El número secreto es menor.
# Intento 3 - Ingresa tu número: 30
# ¡Felicidades! Has adivinado el número secreto: 30

# %%
import random

def adivina_numero():
    secreto = random.randint(1, 50)
    print("Bienvenido al juego <Adivina el Número>")

    for intento in range(1, 100):
        try:
            num = int(input(f"intento {intento} - ingresa tu número: "))
            if num < secreto:
                print("el número secreto es mayor.")
            elif num > secreto:
                print("el número secreto es menor.")
            else:
                print(f"¡FELICIDADES, has adivinado! el numero de intentos fue = {intento}")
                break
        except ValueError:
            print("Por favor, ingrese un número válido.")
adivina_numero()
# Out:
# Bienvenido al juego <Adivina el Número>
# intento 1 - ingresa tu número: 5
# el número secreto es menor.
# intento 2 - ingresa tu número: 2
# el número secreto es mayor.
# intento 3 - ingresa tu número: 4
# ¡FELICIDADES, has adivinado! el numero de intentos fue = 3

# %% [markdown]
# ---
#
# ## Ejercicio 6: Calculadora de Factorial
#
# **Descripción:**
# Crea una función que calcule el factorial de un número entero ingresado por el usuario.
# - La función debe utilizar estructuras de control para iterar (o una solución recursiva) y calcular el factorial.
# - Implementa manejo de excepciones para asegurarte de que el número ingresado es entero y no negativo.
#
# **Ejemplo de salida:**
# Ingrese un número entero para calcular su factorial: 5
# El factorial de 5 es 120

# %%
def calculadora_factorial():
    try:
        n = int(input("ingrese un número entero para calcular su factorial: "))
        if n < 0:
            raise ValueError("el número no puede ser negativo.")
        resultado = 1
        for i in range(1, n + 1):
            resultado *= i
        print(f"el factorial de {n} es {resultado}")
    except ValueError as e:
        print("error:", e)
    except Exception as e:
        print("error inesperado:", e)
calculadora_factorial()
# Out:
# ingrese un número entero para calcular su factorial: 21
# el factorial de 21 es 51090942171709440000

# %% [markdown]
# ---
#
# ## Ejercicio 7: Manejo de Fechas y Horas
#
# **Descripción:**
# Desarrolla una función que reciba una fecha ingresada por el usuario en formato "DD/MM/AAAA" y determine cuántos días faltan para esa fecha a partir de hoy.
# - Importa el módulo `datetime` para trabajar con fechas.
# - Utiliza estructuras de control para validar el formato y maneja excepciones en caso de error en el ingreso de la fecha.
#
# **Ejemplo de salida:**
# Ingrese una fecha (DD/MM/AAAA): 25/12/2023
# Faltan 150 días para el 25/12/2023.

# %%
from datetime import datetime

def dias_para_fecha():
    try:
        fecha_str = input("ingrese una fecha (DD/MM/AAAA): ")
        fecha_obj = datetime.strptime(fecha_str, "%d/%m/%Y")
        hoy = datetime.now()

        if fecha_obj < hoy:
            print("la fecha ya pasó.")
        else:
            dias = (fecha_obj - hoy).days
            print(f"faltan {dias} días para el {fecha_str}.")
    except ValueError:
        print("error: formato de fecha inválido. Use DD/MM/AAAA.")
    except Exception as e:
        print("error inesperado:", e)
dias_para_fecha()
# Out:
# ingrese una fecha (DD/MM/AAAA): 15/09/2025
# faltan 142 días para el 15/09/2025.

# %% [markdown]
# ---
#
# ## Ejercicio 8: Registro de Estudiantes
#
# **Descripción:**
# Implementa un sistema que gestione un registro de estudiantes utilizando un diccionario, donde la clave sea el nombre y el valor la calificación.
# - Crea funciones para agregar un estudiante, actualizar la calificación, eliminar estudiantes y listar todo el registro.
# - Utiliza un bucle para mostrar un menú interactivo al usuario.
# - Maneja excepciones para gestionar errores en la selección de opciones o al intentar modificar un estudiante inexistente.
#
# **Ejemplo de salida:**
# Registro de estudiantes inicial: {'Ana': 90, 'Luis': 78, 'Carlos': 85}
#
# Menú:
#
# Agregar estudiante
#
# Actualizar calificación
#
# Eliminar estudiante
#
# Listar estudiantes
#
# Salir
#
# Opción: 2
# Ingrese el nombre del estudiante: Luis
# Ingrese la nueva calificación: 82
# Estudiante actualizado: Luis - 82
#
# Registro final: {'Ana': 90, 'Luis': 82, 'Carlos': 85}

# %%
def agregar_estudiante(registro):
    try:
        nombre = input("ingrese el nombre del estudiante: ")
        calificacion = float(input(f"ingrese la calificación de {nombre}: "))
        registro[nombre] = calificacion
        print(f"estudiante agregado: {nombre} - {calificacion}")
    except ValueError:
        print("error: La calificación debe ser un número válido.")

def actualizar_calificacion(registro):
    try:
        nombre = input("ingrese el nombre del estudiante: ")
        if nombre not in registro:
            print("error: estudiante no encontrado.")
            return
        nueva_calificacion = float(input(f"ingrese la nueva calificación para {nombre}: "))
        registro[nombre] = nueva_calificacion
        print(f"estudiante actualizado: {nombre} - {nueva_calificacion}")
    except ValueError:
        print("error: la calificación debe ser un número válido.")

def eliminar_estudiante(registro):
    nombre = input("ingrese el nombre del estudiante a eliminar: ")
    if nombre in registro:
        del registro[nombre]
        print(f"estudiante {nombre} eliminado.")
    else:
        print("error: estudiante no encontrado.")

def listar_estudiantes(registro):
    if registro:
        print("lista de estudiantes y sus calificaciones:")
        for nombre, calificacion in registro.items():
            print(f"{nombre}: {calificacion}")
    else:
        print("El registro está vacío.")

def menu():
    registro = {'Elver': 90, 'Pedro': 78, 'Gismondo il custode delle chiavi magiche dell´universo e dell´apocalisse': 85, 'Minu': 90}
    while True:
        print(" Menú: ")
        print("1. Agregar estudiante")
        print("2. Actualizar calificación")
        print("3. Eliminar estudiante")
        print("4. Listar estudiantes")
        print("5. Salir")

        try:
            opcion = int(input("opción: "))
            if opcion == 1:
                agregar_estudiante(registro)
            elif opcion == 2:
                actualizar_calificacion(registro)
            elif opcion == 3:
                eliminar_estudiante(registro)
            elif opcion == 4:
                listar_estudiantes(registro)
            elif opcion == 5:
                print("¡Adiós!")
                break
            else:
                print("opción no válida por favor ingrese una opción del 1 al 5.")
        except ValueError:
            print("error: por favor ingrese un número válido para la opción.")

menu()
# Out:
#  Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# opción: 4
# lista de estudiantes y sus calificaciones:
# Elver: 90
# Pedro: 78
# Gismondo il custode delle chiavi magiche dell´universo e dell´apocalisse: 85
# Minu: 90
#  Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# opción: 1
# ingrese el nombre del estudiante: Juanito
# ingrese la calificación de Juanito: 97
# estudiante agregado: Juanito - 97.0
#  Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# opción: 3
# ingrese el nombre del estudiante a eliminar: Pedro
# estudiante Pedro eliminado.
#  Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# opción: 4
# lista de estudiantes y sus calificaciones:
# Elver: 90
# Gismondo il custode delle chiavi magiche dell´universo e dell´apocalisse: 85
# Minu: 90
# Juanito: 97.0
#  Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# opción: 5
# ¡Adiós!

# %% [markdown]
# ---
#
# ## Ejercicio 9: Generador de Contraseñas Aleatorias
#
# **Descripción:**
# Crea una función que genere una contraseña aleatoria de una longitud especificada por el usuario.
# - Utiliza el módulo `random` junto con la biblioteca `string` para construir la contraseña a partir de letras (mayúsculas y minúsculas), dígitos y caracteres especiales.
# - Valida la entrada y maneja excepciones para asegurarte de que la longitud es un número entero positivo.
#
# **Ejemplo de salida:**
# Ingrese la longitud deseada para la contraseña: 10
# Contraseña generada: A8b#K3d!Qz

# %%
import random
import string

def generar_contraseña():
    try:
        longitud = int(input("ingrese el tamaño deseado para la contraseña: "))
        if longitud <= 0:
            raise ValueError("el tamaño debe ser un número entero positivo.")

        caracteres = string.ascii_letters + string.digits + string.punctuation
        contraseña = ''.join(random.choice(caracteres) for _ in range(longitud))
        print("contraseña generada:", contraseña)

    except ValueError:
        print("error: por favor ingrese un número entero positivo valido.")
    except Exception as e:
        print("error inesperado:", e)

generar_contraseña()
# Out:
# ingrese el tamaño deseado para la contraseña: 5
# contraseña generada: Sli+h

# %% [markdown]
# ---
#
# ## Ejercicio 10: Buscador de Archivos en un Directorio
#
# **Descripción:**
# Desarrolla una función que reciba el nombre de un directorio y una subcadena para buscar archivos cuyo nombre la contenga.
# - Utiliza el módulo `os` para listar el contenido del directorio.
# - Aplica estructuras de control para filtrar los archivos según la subcadena.
# - Implementa manejo de excepciones para controlar errores como directorio no existente o permisos insuficientes.
#
# **Ejemplo de salida:**
# Ingrese la ruta del directorio: /ruta/al/directorio
# Ingrese la subcadena a buscar: reporte
# Archivos encontrados que contienen "reporte":
#
# reporte_enero.pdf
#
# reporte_febrero.xlsx
#
# resumen_reporte.txt

# %%
import os

def buscar_archivos():
    try:
        ruta = input("ingrese el sitio del directorio: ")
        subcadena = input("ingrese la subcadena a buscar: ")

        if not os.path.isdir(ruta):
            raise FileNotFoundError("el directorio no existe.")

        archivos = os.listdir(ruta)
        encontrados = [archivo for archivo in archivos if subcadena in archivo]

        if encontrados:
            print(f'archivos encontrados que contienen "{subcadena}":')
            for archivo in encontrados:
                print(archivo)
        else:
            print(f'no se encontraron archivos que contengan "{subcadena}".')

    except Exception as e:
        print("error:", e)

buscar_archivos()
