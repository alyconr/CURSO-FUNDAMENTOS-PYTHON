# %% [markdown]
# Apropiación [Ejercicios Cíclicos]

# %% [markdown]
# 1.Leer un número y presentar la tabla de multiplicar de ese número entre 1 y 10.
# Utilizar el siguiente formato de ejemplo:
#
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5

# %%
numero = int(input("Ingrese un número: "))
for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")
# Out:
# Ingrese un número: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# En un partido de fútbol, se ofrece un descuento a los aficionados que depende del estrato y la edad. Si el estrato es 1 y su edad es menor a 18 el descuento será del 20% sobre el valor de la boleta. Si el estrato es 1 y el alumno tiene 18 o mas años, el descuento será del 15%. Si el estrato es 2 y la edad es menor a 18 años, el descuento será del 10% y si el estrato es 2 y la edad es 18 años o más, el descuento será del 5%. Determinar el total del dinero recaudado y descontado por las últimas N personas que ingresan al partido.
#
#
# total_recaudado = 0
# for
# total_recaudado = total_recaudado + pago

# %%
estrato = int(input("Ingrese el estrato (1, 2, 3): "))
edad = int(input("Ingrese la edad: "))
pago = float(input("Ingrese el valor de la boleta: "))
descuento = 0
if estrato == 1 and edad < 18:
    descuento = 0.2
elif estrato == 1 and edad >= 18:
    descuento = 0.15

elif estrato == 2 and edad < 18:
    descuento = 0.1
elif estrato == 2 and edad >= 18:
    descuento = 0.05

total_recaudado = pago * (1 - descuento)
print("Total recaudado:", total_recaudado)
# Out:
# Ingrese el estrato (1, 2, 3): 2
# Ingrese la edad: 17
# Ingrese el valor de la boleta: 50000
# Total recaudado: 45000.0

# %% [markdown]
# Leer un password de ingreso a un programa y mostrar el mensaje de bienvenida si es correcto. Mientras no lo sea, debe mostrar el mensaje de Password incorrecto. El programa debe terminar automáticamente al quinto intento fallido.

# %%
password = input("Ingrese el password: ")
for i in range(5):
  if password == "12345":
    print("Bienvenido")
    break
  else:
    print("Password incorrecto", i)
    password = input("Ingrese el password: ")
    print("Intento fallido")
# Out:
# Ingrese el password: 221
# Password incorrecto 0
# Ingrese el password: 1515
# Intento fallido
# Password incorrecto 1
# Ingrese el password: 5151
# Intento fallido
# Password incorrecto 2
# Ingrese el password: 534534
# Intento fallido
# Password incorrecto 3
# Ingrese el password: 5454
# Intento fallido
# Password incorrecto 4
# Ingrese el password: 53454
# Intento fallido
