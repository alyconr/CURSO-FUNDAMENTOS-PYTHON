# %% [markdown]
# <a href="https://colab.research.google.com/github/Luiisita/CURSO-FUNDAMENTOS-PYTHON_L/blob/Rama-solucion/Evaluaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 inventario = ["carpeta","lapiz","regla","cuaderno"]
cantidad_productos = [20,40,50,30]
stock =10

for i in range (len(inventario)):
  print(f"{i + 1}. {inventario[i]}: {cantidad_productos[i]}")
  if cantidad_productos [i] < stock:
    print("El producto esta por debajo del stock: ")
    print(f"El inventario {inventario[i]} no tiene suficiente stock: {cantidad_productos[i]} cantidad_productos")

inventario_seleccionado = int(input("ingrese el numero del producto que se desea actualizar: "))
valor = int (input("ingrese la nueva cantidad: "))

cantidad_productos[inventario_seleccionado - 1] = valor

for i in range (len(inventario)):
  print(f"{i + 1}. {inventario[i]}: {cantidad_productos[i]}")
  if cantidad_productos [i] < stock:
    print("El producto esta por debajo del stock: ")
    print(f"el inventario {inventario[i]} no tiene suficiente stock: {cantidad_productos[i]} cantidad_productos")
# Out:
# 1. carpeta: 20
# 2. lapiz: 40
# 3. regla: 50
# 4. cuaderno: 30
# ingrese el numero del producto que se desea actualizar: 4
# ingrese la nueva cantidad: 80
# 1. carpeta: 20
# 2. lapiz: 40
# 3. regla: 50
# 4. cuaderno: 80

# %%
parrafo= input("ingese el parrafo: ").lower()
print(parrafo)

buscar_palabra =(input("ingrese la palabra que quiere buscar: "))


numero_palabra = parrafo.count(buscar_palabra)

print(f"la palabra  ´{buscar_palabra}' esta '{numero_palabra}' veces en el parrafo")
# Out:
# ingese el parrafo: mañana no hay clase, hay paro
# mañana no hay clase, hay paro
# ingrese la palabra que quiere buscar: hay
# la palabra  ´hay' esta '2' veces en el parrafo

# %%
frase = input("ingrse una frase: ")
print(frase.split())
frase_final = "".join(char for char in frase if char.isalpha() or char.isspace())
print(frase_final)
frase_tupla = tuple(frase_final)
frase_ordenada = tuple(sorted(frase_tupla))
print("Letras ordenadas:", frase_ordenada)
# Out:
# ingrse una frase: hola--Buenas tardes como se encuentra?
# ['hola--Buenas', 'tardes', 'como', 'se', 'encuentra?']
# holaBuenas tardes como se encuentra
# Letras ordenadas: (' ', ' ', ' ', ' ', 'B', 'a', 'a', 'a', 'a', 'c', 'c', 'd', 'e', 'e', 'e', 'e', 'e', 'h', 'l', 'm', 'n', 'n', 'n', 'o', 'o', 'o', 'r', 'r', 's', 's', 's', 't', 't', 'u', 'u')

# %%
def mostrar_menu():
    print("\n Menú:")
    print("1. Agregar nuevo Estudiante")
    print("2. Listar todos los Estudiantes")
    print("3. Consultar calificación de un estudiante")
    print("4. Actualizar calificación de un estudiante")
    print("5. Eliminar un estudiante del registro")
    print("6. Salir")

# Diccionario con estudiantes y calificaciones predefinidos
registros = {
    "Juan Pérez": 85,
    "María Gómez": 92,
    "Carlos Ruiz": 78,
    "Ana López": 88
}

for reg in registros:
  print(reg)

while True:
    mostrar_menu()
    opcion = input("Elige una opción: ")

    if opcion == "1":
        nombre = input("Ingrese el nombre del estudiante: ").strip()
        if nombre in registros:
            print("El estudiante ya está registrado.")
        else:
            try:
                calificacion = float(input("Ingrese la calificación: "))
                registros[nombre] = calificacion
                print(f" Registro agregado: {nombre} - {calificacion}")
            except ValueError:
                print(" La calificación debe ser un número.")

    elif opcion == "2":
        if registros:
            print("\n Lista de calificaciones:")
            for nombre, calificacion in registros.items():
                print(f"- {nombre}: {calificacion}")
        else:
            print(" No hay registros disponibles.")

    elif opcion == "3":
        nombre = input("Ingrese el nombre del estudiante a consultar: ").strip()
        if nombre in registros:
            print(f" {nombre} tiene una calificación de {registros[nombre]}")
        else:
            print(" Estudiante no encontrado.")

    elif opcion == "4":
        nombre = input("Ingrese el nombre del estudiante que quiere actualizar: ").strip()
        if nombre in registros:
            try:
                nueva_calificacion = float(input(f"Ingrese la nueva calificación para {nombre}: "))
                registros[nombre] = nueva_calificacion
                print(f" Calificación actualizada: {nombre} - {nueva_calificacion}")
            except ValueError:
                print(" La calificación debe ser un número.")
        else:
            print("Estudiante no encontrado.")

    elif opcion == "5":
        nombre = input("Ingrese el nombre del estudiante que quiere eliminar: ").strip()
        if nombre in registros:
            del registros[nombre]
            print(f"{nombre} ha sido eliminado del registro.")
        else:
            print(" Estudiante no encontrado.")

    elif opcion == "6":
        print(" Saliendo del programa. ¡Hasta luego!")
        break

    else:
        print(" Opción no válida. Intenta de nuevo.")
# Out:
# Juan Pérez
# María Gómez
# Carlos Ruiz
# Ana López
#
#  Menú:
# 1. Agregar nuevo Estudiante
# 2. Listar todos los Estudiantes
# 3. Consultar calificación de un estudiante
# 4. Actualizar calificación de un estudiante
# 5. Eliminar un estudiante del registro
# 6. Salir
# Elige una opción: 1
# Ingrese el nombre del estudiante: Laura Tovar
# Ingrese la calificación: 80
#  Registro agregado: Laura Tovar - 80.0
#
#  Menú:
# 1. Agregar nuevo Estudiante
# 2. Listar todos los Estudiantes
# 3. Consultar calificación de un estudiante
# 4. Actualizar calificación de un estudiante
# 5. Eliminar un estudiante del registro
# 6. Salir
# Elige una opción: 2
#
#  Lista de calificaciones:
# - Juan Pérez: 85
# - María Gómez: 92
# - Carlos Ruiz: 78
# - Ana López: 88
# - Laura Tovar: 80.0
#
#  Menú:
# 1. Agregar nuevo Estudiante
# 2. Listar todos los Estudiantes
# 3. Consultar calificación de un estudiante
# 4. Actualizar calificación de un estudiante
# 5. Eliminar un estudiante del registro
# 6. Salir
# ...

# %%
numeros={1,5,15,4,21,7}
print("Lista de Numeros Predefinidos:", numeros)

def mostrar_menu():
  print("\nMenú de Operaciones")
  print("1. Calcular Promedio")
  print("2. Identificar el valor máximo")
  print("3. Identificar el valor minimo")
  print("4. Eliminar un Número")
  print("5. Salir")

def mostrar_numeros(numeros):
  print("Números actuales:")

def calcular_promedio(numeros):
  suma = sum(numeros)
  promedio = suma / len(numeros)
  return promedio
  print(f"El promedio es: {promedio}")

def Identificar_maximo(numeros):
  mayor = max(numeros)
  return mayor
  print(f"El número máximo es: {mayor}")

def Identificar_minimo(numeros):
    minimo = min(numeros)
    return minimo
    print(f"El número mínimo es: {minimo}")

def eliminar_numero(numeros):
  numero_eliminar = int(input("Ingrese el número que desea eliminar: "))
  if numero_eliminar in numeros:
    numeros.remove(numero_eliminar)
    print(f"{numero_eliminar} ha sido eliminado de la lista.")




while True:
  mostrar_menu()
  opcion = input("Elige una opción: ")

  if opcion == "1":
    promedio = calcular_promedio(numeros)
    print(f"El promedio es: {promedio}")

  elif opcion == "2":
    mayor = Identificar_maximo(numeros)
    print(f"El número máximo es: {mayor}")

  elif opcion == "3":
    minimo = Identificar_minimo(numeros)
    print(f"El número mínimo es: {minimo}")

  elif opcion == "4":
    eliminar_numero(numeros)
    print(f"Números actuales: {numeros}")

  elif. opcion == "5":
    print("Saliendo del programa.")
    break

  else:
    print("Opción no válida. Intenta de nuevo.")
# Out:
# Lista de Numeros Predefinidos: {1, 4, 5, 21, 7, 15}
#
# Menú de Operaciones
# 1. Calcular Promedio
# 2. Identificar el valor máximo
# 3. Identificar el valor minimo
# 4. Eliminar un Número
# 5. Salir
# Elige una opción: 1
# El promedio es: 8.833333333333334
#
# Menú de Operaciones
# 1. Calcular Promedio
# 2. Identificar el valor máximo
# 3. Identificar el valor minimo
# 4. Eliminar un Número
# 5. Salir
# Elige una opción: 2
# El número máximo es: 21
#
# Menú de Operaciones
# 1. Calcular Promedio
# 2. Identificar el valor máximo
# 3. Identificar el valor minimo
# 4. Eliminar un Número
# 5. Salir
# Elige una opción: 3
# El número mínimo es: 1
#
# Menú de Operaciones
# 1. Calcular Promedio
# 2. Identificar el valor máximo
# 3. Identificar el valor minimo
# 4. Eliminar un Número
# 5. Salir
# Elige una opción: 4
# Ingrese el número que desea eliminar: 21
# 21 ha sido eliminado de la lista.
# Números actuales: {1, 4, 5, 7, 15}
#
# Menú de Operaciones
# 1. Calcular Promedio
# ...
