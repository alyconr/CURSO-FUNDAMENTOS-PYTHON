# %% [markdown]
# <a href="https://colab.research.google.com/github/Luiisita/CURSO-FUNDAMENTOS-PYTHON_L/blob/Rama-solucion/Apropiacion_En_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##APROPIACIÓN FUNCIIONES

# %% [markdown]
# ##1.
# Realiza una función que tome una lista de números enteros y devuelva dos listas ordenadas. La primera con los números pares y la segunda con los números impares.

# %%
 def numeros (lista):
    numeros_pares= []
    numeros_impares=[]
    for numero in lista:
       if int (numero)% 2 == 0:
           numeros_pares.append(int(numero))
       else:
          numeros_impares.append(int(numero))


    numeros_pares.sort()
    numeros_impares.sort()
    return numeros_pares, numeros_impares

lista_numeros = [10, 3, 7, 8, 6, 1, 9, 2]
pares, impares = numeros(lista_numeros)

print("Lista de pares ordenados:", pares)
print("Lista de impares ordenados:", impares)




def agregar_una_vez(lista, el):

    try:

        if el in lista:
            raise ValueError(f"Error: Imposible añadir elementos duplicados => {el}")
        else:
            lista.append(el)
    except ValueError as e:
        print(e)
        return lista
    finally:
        print(lista)
        print("GRACIAS POR USAR ESTE PROGRAMA")
# Out:
# Lista de pares ordenados: [2, 6, 8, 10]
# Lista de impares ordenados: [1, 3, 7, 9]

# %% [markdown]
# ##2
# Realiza una función que reciba una palabra y devuelva un diccionario donde las claves sean las diferentes letras que se encuentran en la palabra y los valores sean el número de veces que se repite cada letra en la palabra

# %%
def contar_letras(palabra):
    diccionario = {}
    for letra in palabra:
        if letra in diccionario:
            diccionario[letra] += 1
        else:
            diccionario[letra] = 1
    return diccionario

palabra_usuario = input("Ingresa una palabra: ")

resultado = contar_letras(palabra_usuario)
print("Conteo de letras:", resultado)
# Out:
# Ingresa una palabra: Colombia
# Conteo de letras: {'C': 1, 'o': 2, 'l': 1, 'm': 1, 'b': 1, 'i': 1, 'a': 1}

# %%
def contar_letras(palabra):
    contador = {}
    for letra in palabra:
        if letra in contador:
            contador[letra] += 1
        else:
            contador[letra] = 1
    return contador
resultado = contar_letras("Colombia")
print(resultado)
# Out:
# {'C': 1, 'o': 2, 'l': 1, 'm': 1, 'b': 1, 'i': 1, 'a': 1}

# %% [markdown]
# ##3
# Realiza una función que reciba un número y devuelva una cadena con los nombres de los números recibidos, separando cada número con un guión medio. Por ejemplo, si el número recibido es 134, la función devolverá la cadena "uno - tres - cuatro"

# %%
def cadena_devuelta(numero):
    numeros = {1:"uno", 2:"dos", 3:"tres", 4:"cuatro", 5:"cinco"}
    return "-".join(numeros[int(d)] for d in str(numero) if int(d) in numeros)

cadena_devuelta(1234)
# Out:
# 'uno-dos-tres-cuatro'

# %% [markdown]
# ##APROPIACION ERRORES

# %% [markdown]
# ##1
# Finaliza el siguiente código con una gestión completa de sus excepciones. El objetivo del programa es solicitar al usuario una posición de una lista y devolver el valor que se encuentra en dicha posición. Prueba el programa enviando una posición inexistente y enviando una letra como posición. El programa sólo terminará cuando se ejecute correctamente.

# %%
while True:
    try:
        lista = [3,5,6,8]
        pos = int(input("ingrese la posición del elemento que desea obtener:"))
        print(f"El valor en la posicion {pos} es {lista[pos]}")
        break
    except IndexError:
      print ("El indice está fuera del rango")
    except ValueError:
      print ("Solo se permiten numeros enteros")
# Out:
# ingrese la posición del elemento que desea obtener:7
# El indice está fuera del rango
# ingrese la posición del elemento que desea obtener:3
# El valor en la posicion 3 es 8

# %% [markdown]
# ##2
#  Realiza una función llamada agregar_una_vez(lista, el) que reciba una lista y un elemento. La función debe añadir el elemento al final de la lista con la condición de no repetir ningún elemento. Además si este elemento ya se encuentra en la lista se debe invocar un error de tipo ValueError que debes capturar y mostrar este mensaje en su lugar: Error: Imposible añadir elementos duplicados => [elemento]. Mostrar el siguiente mensaje siempre que se ejecute independientemente de que la ejecución haya sido exitosa o no
#
# Gracias por usar este programa

# %%
#Realiza una función llamada agregar_una_vez(lista, el) que reciba una lista y un elemento. La función debe añadir el elemento al final de la lista con la condición de no repetir ningún elemento. Además si este elemento ya se encuentra en la lista se debe invocar un error de tipo ValueError que debes capturar y mostrar este mensaje en su lugar:
def agregar_una_vez(lista, el):

    try:

        if el in lista:
            raise ValueError(f"Error: Imposible añadir elementos duplicados => {el}")
        else:
            lista.append(el)
    except ValueError as e:
        print(e)
        return lista
    finally:
        print(lista)
        print("GRACIAS POR USAR ESTE PROGRAMA")




agregar_una_vez(lista=["a", "b", "c"], el="c")
# Out:
# Error: Imposible añadir elementos duplicados => c
# ['a', 'b', 'c']
# GRACIAS POR USAR ESTE PROGRAMA
# ['a', 'b', 'c']
